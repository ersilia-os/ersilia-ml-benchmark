# %%
benchmarks = {
    "tdcommons/bioavailability-ma":0.729,
    "tdcommons/hia-hou":0.989,
    "tdcommons/pgp-broccatelli":0.954,
    "tdcommons/bbb-martins":0.933,
    "tdcommons/cyp2c9-veith":0.895,
    "tdcommons/cyp2d6-veith":0.801,
    "tdcommons/cyp3a4-veith":0.919,
    "tdcommons/cyp2c9-substrate-carbonmangels":0.478,
    "tdcommons/cyp2d6-substrate-carbonmangels":0.719,
    "tdcommons/cyp3a4-substrate-carbonmangels":0.696,
    "tdcommons/herg":0.891,
    "tdcommons/ames":0.868,
    "tdcommons/dili":0.933
}

names = []

for b in benchmarks.keys():
    names += [b.split("/")[1]]

names
# Out:
# ['bioavailability-ma',
#  'hia-hou',
#  'pgp-broccatelli',
#  'bbb-martins',
#  'cyp2c9-veith',
#  'cyp2d6-veith',
#  'cyp3a4-veith',
#  'cyp2c9-substrate-carbonmangels',
#  'cyp2d6-substrate-carbonmangels',
#  'cyp3a4-substrate-carbonmangels',
#  'herg',
#  'ames',
#  'dili']

# %%
import pandas as pd
for n in names:
    smi = pd.read_csv(f"../descriptors/smiles_train_{n}.csv")
    y = pd.read_csv(f"../descriptors/y_train_{n}.csv")
    df = pd.DataFrame({"smiles": smi["smiles"].tolist(), "y_true": y["y_true"].tolist()})
    df.to_csv(f"train_{n}.csv", index=False)

# %%
for n in names:
    print(f"../models/{n}.csv")
# Out:
# ../models/bioavailability-ma.csv
# ../models/hia-hou.csv
# ../models/pgp-broccatelli.csv
# ../models/bbb-martins.csv
# ../models/cyp2c9-veith.csv
# ../models/cyp2d6-veith.csv
# ../models/cyp3a4-veith.csv
# ../models/cyp2c9-substrate-carbonmangels.csv
# ../models/cyp2d6-substrate-carbonmangels.csv
# ../models/cyp3a4-substrate-carbonmangels.csv
# ../models/herg.csv
# ../models/ames.csv
# ../models/dili.csv
